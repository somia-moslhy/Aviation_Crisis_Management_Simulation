# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\somia\files\programe_files\Airline_project\Airlines_db\flights.csv')
df.head()
# Out:
# C:\Users\A H M E D\AppData\Local\Temp\ipykernel_14704\426037706.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'D:\somia\files\programe_files\Airline_project\Airlines_db\flights.csv')
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# ...

# %%
# Skip bad lines and use the python engine
df = pd.read_csv(r'D:\somia\files\programe_files\Airline_project\Airlines_db\flights.csv', engine='python', on_bad_lines='skip')

# %%
sampled_df = df.sample(n=1000, random_state=42)
sampled_df.head()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1508570  2015      4    7            2      EV           4900      N759EV
# 363270   2015      1   24            6      AS            611      N413AS
# 3003945  2015      7    8            3      WN           1483      N463WN
# 2291425  2015      5   26            2      WN            193      N7745A
# 2973084  2015      7    6            1      UA            253      N213UA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 1508570            FWA                 DTW                 1340  ...
# 363270             LAS                 SEA                 1910  ...
# 3003945            OAK                 SEA                  630  ...
# 2291425            STL                 DAL                  810  ...
# 2973084            IAH                 HNL                 1000  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
sampled_df.to_csv(r'D:\somia\files\programe_files\Airline_project\Airlines_db\sampled_flights.csv', index=False)
